# %% [markdown]
# # Single-Shot CNN Denoising
#
# We demonstrate that a deep neural net can be trained to denoise a _single_ noisy image, taking advantage of the fact that one 512 x 512 image contains ~250,000 dimensions of information.

# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
# %gui qt

# %%
import sys
sys.path.append("..")

# %%
from util import show, plot_images, plot_tensors

# %%
import numpy as np
import matplotlib.pyplot as plt
from skimage.morphology import disk
from skimage.filters import gaussian, median
from skimage import data, img_as_float, img_as_ubyte
from skimage.color import gray2rgb
from skimage.util import random_noise
from skimage.measure import compare_psnr

# %%
from skimage.io import imread, imsave

# %%
plt.rc('figure', figsize = (5,5))

# %%
from skimage import transform
image = imread('../figs/NewYork.png')#numpy
image = image[:,:,1]
image = transform.resize(image, (1024, 1024))
show(image)
#print(image.shape)

# %%
image = image[512 - 128:512+128, 512 - 128:512+128]
show(image)

# %%
# import napari
# viewer = napari.view_image(image)

# %%
torch.permute?
# Out:
# Object `torch.permute` not found.

# %%
def split_tiles(x, tile_width):
    batch, channel, width, height = x.shape
    n_tiles = (width//tile_width)*(height//tile_width)
    return (torch.nn.Unfold(tile_width, stride=tile_width)(x)
            .permute(2, 0, 1)
            .reshape([n_tiles, 1, tile_width, tile_width]))

def merge_tiles(x, tile_width):
    batch, channel, tile_width, tile_height = x.shape
    n_tiles = (width//tile_width)*(height//tile_width)
    return (torch.nn.Unfold(tile_width, stride=tile_width)(x)
            .permute(2, 0, 1)
            .reshape([n_tiles, 1, tile_width, tile_width]))

# %%
np.random.seed(3)
noisy_image = random_noise(image, mode = 'gaussian', var=0.01)
noisy_image2 = random_noise(image, mode = 'gaussian', var=0.01)
show(noisy_image)

# %%
imsave('../figs/NoisyNewYork.png', np.clip(noisy_image, 0, 1))
# Out:
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.

# %%
# viewer.add_image(noisy_image)
# viewer.add_image(noisy_image2)

# %%
import torch
noisy = torch.Tensor(noisy_image[np.newaxis, np.newaxis])
clean = torch.Tensor(img_as_float(image)[np.newaxis, np.newaxis])
noisy2 = torch.Tensor(noisy_image2[np.newaxis, np.newaxis])

# %%
plot_tensors([noisy, clean])

# %%
clean = split_tiles(clean, 32)
noisy = split_tiles(noisy, 32)

# %%
noisy.shape
# Out:
# torch.Size([64, 1, 32, 32])

# %%
building_idx = [12, 13, 19, 20, 21, 22]
nonbuilding_idx = [x for x in range(len(clean)) if x not in building_idx]

# %%
clean = torch.index_select(clean, 0, torch.tensor(nonbuilding_idx))
noisy = torch.index_select(noisy, 0, torch.tensor(nonbuilding_idx))

# %%
plot_tensors(clean[10:20])

# %%
plot_tensors(clean[20:30])

# %%
plot_tensors(clean[30:40])

# %%
from util import getbestgpu
#device = getbestgpu()

# %% [markdown]
# # Model

# %% [markdown]
# For our model, we use a short UNet with two levels of up- and down- sampling

# %%
from models.babyunet import BabyUnet
from models.unet import Unet
from models.dncnn import DnCNN, DnCNNKernel, ResCNN

from models.kernelpredicting import KernelPredicting

model = DnCNN(1, 1, 6)
# model = ResCNN(1, 32, 8)
model = KernelPredicting(1, DnCNN, kernel_width=15,
                         depth= 6,
                          features= 32)

# %%
sum(p.numel() for p in model.parameters() if p.requires_grad)
# Out:
# 102208

# %%
image.ravel().shape
# Out:
# (65536,)

# %% [markdown]
# # Training

# %%
from torch.nn import MSELoss, L1Loss
from torch.optim import Adam

loss_function = MSELoss()
optimizer = Adam(model.parameters(), lr=0.01)

# %%
noisy.shape
# Out:
# torch.Size([58, 1, 32, 32])

# %%
# model = model.to(device)
# noisy = noisy.to(device)

# %%
losses = []
val_losses = []
best_images = []
best_val_loss = loss_function(noisy, 0*noisy)

net_input = noisy

for i in range(500):
    model.train()
    
    net_output = model(net_input)
    
    loss = loss_function(net_output, clean)
    
    optimizer.zero_grad()
 
    loss.backward()
    
    optimizer.step()
    losses.append(loss.item())
    
    if i % 5 == 0:
        print("Loss (", i, "): \t", round(loss.item(), 4))
        
        model.eval()
    
        val_loss = loss_function(net_output, clean)
        
        print("PSNR (", i, "): \t", round(-10*np.log10(val_loss.item()), 2))
        val_losses.append(val_loss.item())

        if val_loss < best_val_loss:
            best_val_loss = val_loss
            best_images.append(model(net_input).detach().cpu())
#           best_psnr = compare_psnr(np.clip(best_images[-1][0,0].numpy(), 0, 1), img_as_float(image))
#           print("Best PSNR: ", np.round(best_psnr, 2))
# Out:
# Loss ( 0 ): 	 0.0339
# PSNR ( 0 ): 	 14.69
# Loss ( 5 ): 	 0.0026
# PSNR ( 5 ): 	 25.89
# Loss ( 10 ): 	 0.0018
# PSNR ( 10 ): 	 27.48
# Loss ( 15 ): 	 0.0017
# PSNR ( 15 ): 	 27.81
# Loss ( 20 ): 	 0.0016
# PSNR ( 20 ): 	 28.05
# Loss ( 25 ): 	 0.0015
# PSNR ( 25 ): 	 28.27
# Loss ( 30 ): 	 0.0014
# PSNR ( 30 ): 	 28.43
# Loss ( 35 ): 	 0.0014
# PSNR ( 35 ): 	 28.58
# Loss ( 40 ): 	 0.0013
# PSNR ( 40 ): 	 28.71
# Loss ( 45 ): 	 0.0013
# PSNR ( 45 ): 	 28.83
# Loss ( 50 ): 	 0.0013
# PSNR ( 50 ): 	 28.94
# Loss ( 55 ): 	 0.0012
# PSNR ( 55 ): 	 29.04
# Loss ( 60 ): 	 0.0012
# PSNR ( 60 ): 	 29.12
# Loss ( 65 ): 	 0.0012
# PSNR ( 65 ): 	 29.2
# Loss ( 70 ): 	 0.0012
# PSNR ( 70 ): 	 29.28
# Loss ( 75 ): 	 0.0012
# PSNR ( 75 ): 	 29.35
# Loss ( 80 ): 	 0.0011
# PSNR ( 80 ): 	 29.42
# Loss ( 85 ): 	 0.0011
# PSNR ( 85 ): 	 29.5
# Loss ( 90 ): 	 0.0011
# PSNR ( 90 ): 	 29.56
# Loss ( 95 ): 	 0.0011
# PSNR ( 95 ): 	 29.64
# Loss ( 100 ): 	 0.0011
# PSNR ( 100 ): 	 29.69
# Loss ( 105 ): 	 0.0011
# PSNR ( 105 ): 	 29.71
# Loss ( 110 ): 	 0.001
# PSNR ( 110 ): 	 29.84
# Loss ( 115 ): 	 0.001
# PSNR ( 115 ): 	 29.85
# Loss ( 120 ): 	 0.001
# PSNR ( 120 ): 	 29.93
# Loss ( 125 ): 	 0.001
# PSNR ( 125 ): 	 30.06
# Loss ( 130 ): 	 0.001
# PSNR ( 130 ): 	 30.13
# Loss ( 135 ): 	 0.0009
# PSNR ( 135 ): 	 30.27
# Loss ( 140 ): 	 0.001
# PSNR ( 140 ): 	 30.11
# Loss ( 145 ): 	 0.001
# PSNR ( 145 ): 	 30.13
# Loss ( 150 ): 	 0.0009
# PSNR ( 150 ): 	 30.24
# Loss ( 155 ): 	 0.0009
# PSNR ( 155 ): 	 30.42
# Loss ( 160 ): 	 0.0009
# PSNR ( 375 ): 	 35.2
# Loss ( 380 ): 	 0.0003
# PSNR ( 380 ): 	 35.13
# Loss ( 385 ): 	 0.0003
# PSNR ( 385 ): 	 35.19
# Loss ( 390 ): 	 0.0003
# PSNR ( 390 ): 	 35.42
# Loss ( 395 ): 	 0.0003
# PSNR ( 395 ): 	 35.38
# Loss ( 400 ): 	 0.0003
# PSNR ( 400 ): 	 35.3
# Loss ( 405 ): 	 0.0003
# PSNR ( 405 ): 	 35.7
# Loss ( 410 ): 	 0.0002
# PSNR ( 410 ): 	 36.12
# Loss ( 415 ): 	 0.0002
# PSNR ( 415 ): 	 36.11
# Loss ( 420 ): 	 0.0003
# PSNR ( 420 ): 	 35.39
# Loss ( 425 ): 	 0.0003
# PSNR ( 425 ): 	 35.16
# Loss ( 430 ): 	 0.0003
# PSNR ( 430 ): 	 35.64
# Loss ( 435 ): 	 0.0002
# PSNR ( 435 ): 	 36.16
# Loss ( 440 ): 	 0.0002
# PSNR ( 440 ): 	 36.53
# Loss ( 445 ): 	 0.0002
# PSNR ( 445 ): 	 36.7
# Loss ( 450 ): 	 0.0002
# PSNR ( 450 ): 	 36.9
# Loss ( 455 ): 	 0.0002
# PSNR ( 455 ): 	 36.82
# Loss ( 460 ): 	 0.0003
# PSNR ( 460 ): 	 35.38
# Loss ( 465 ): 	 0.0003
# PSNR ( 465 ): 	 35.81
# Loss ( 470 ): 	 0.0002
# PSNR ( 470 ): 	 36.26
# Loss ( 475 ): 	 0.0002
# PSNR ( 475 ): 	 36.86
# Loss ( 480 ): 	 0.0002
# PSNR ( 480 ): 	 37.09
# Loss ( 485 ): 	 0.0002
# PSNR ( 485 ): 	 37.02
# Loss ( 490 ): 	 0.0002
# PSNR ( 490 ): 	 37.46
# Loss ( 495 ): 	 0.0002
# PSNR ( 495 ): 	 37.66

# %%
plt.plot(losses)

# %%
denoised = model(net_input).detach()

# %%
plot_tensors(noisy[::9])

# %%
plot_tensors(denoised[::9])

# %%
plot_tensors(clean[::9])

# %%
torch.nn.Fold()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-77-a224553349a4> in <module>
# ----> 1 torch.nn.Fold()
#
# TypeError: __init__() missing 2 required positional arguments: 'output_size' and 'kernel_size'

# %%
model.dncnn(net_input).shape
# Out:
# ---------------------------------------------------------------------------
# ModuleAttributeError                      Traceback (most recent call last)
# <ipython-input-78-e8ac38581c70> in <module>
# ----> 1 model.dncnn(net_input).shape
#
# /home/disk/disk1/LiuTQ/anaconda3/lib/python3.7/site-packages/torch/nn/modules/module.py in __getattr__(self, name)
#     770                 return modules[name]
#     771         raise ModuleAttributeError("'{}' object has no attribute '{}'".format(
# --> 772             type(self).__name__, name))
#     773
#     774     def __setattr__(self, name: str, value: Union[Tensor, 'Module']) -> None:
#
# ModuleAttributeError: 'KernelPredicting' object has no attribute 'dncnn'

# %%
k = 2
kernel_width = 7
shape = [1, 1, kernel_width, kernel_width]

plot_tensors(
            torch.softmax(model.dncnn(net_input), 1)[:, :, 16, 12]
                 .reshape([net_input.shape[0], 1, kernel_width, kernel_width])[::9]
)
# Out:
# ---------------------------------------------------------------------------
# ModuleAttributeError                      Traceback (most recent call last)
# <ipython-input-79-57f4f4b7fb49> in <module>
#       4
#       5 plot_tensors(
# ----> 6             torch.softmax(model.dncnn(net_input), 1)[:, :, 16, 12]
#       7                  .reshape([net_input.shape[0], 1, kernel_width, kernel_width])[::9]
#       8 )
#
# /home/disk/disk1/LiuTQ/anaconda3/lib/python3.7/site-packages/torch/nn/modules/module.py in __getattr__(self, name)
#     770                 return modules[name]
#     771         raise ModuleAttributeError("'{}' object has no attribute '{}'".format(
# --> 772             type(self).__name__, name))
#     773
#     774     def __setattr__(self, name: str, value: Union[Tensor, 'Module']) -> None:
#
# ModuleAttributeError: 'KernelPredicting' object has no attribute 'dncnn'

# %%
plot_tensors(clean[9*4:9*4+2])
